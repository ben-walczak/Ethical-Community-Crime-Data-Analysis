# %% [markdown]
# # Version Control
# Check and display versions for future reproduction and debugging purposes

# %%
import pandas as pd
import sklearn
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns; sns.set()

pd.show_versions()
# Out:
# INSTALLED VERSIONS
# ------------------
# commit: None
# python: 3.6.6.final.0
# python-bits: 64
# OS: Windows
# OS-release: 10
# machine: AMD64
# processor: Intel64 Family 6 Model 61 Stepping 4, GenuineIntel
# byteorder: little
# LC_ALL: None
# LANG: None
# LOCALE: None.None
#
# pandas: 0.23.4
# pytest: 3.8.2
# pip: 10.0.1
# setuptools: 40.4.3
# Cython: 0.28.5
# numpy: 1.15.2
# scipy: 1.1.0
# pyarrow: None
# xarray: None
# IPython: 7.0.1
# sphinx: 1.8.1
# patsy: 0.5.0
# dateutil: 2.7.3
# pytz: 2018.5
# blosc: None
# bottleneck: 1.2.1
# tables: 3.4.4
# numexpr: 2.6.8
# feather: None
# matplotlib: 2.2.2
# openpyxl: 2.5.8
# xlrd: 1.1.0
# xlwt: 1.3.0
# xlsxwriter: 1.1.1
# lxml: 4.2.5
# bs4: 4.6.3
# html5lib: 1.0.1
# sqlalchemy: 1.2.11
# pymysql: None
# psycopg2: None
# jinja2: 2.10
# s3fs: None
# fastparquet: None
# pandas_gbq: None
# pandas_datareader: 0.7.0

# %%
raw_df = pd.read_csv('data/crimedata.csv')
df = raw_df.replace('?',np.nan)
df.tail()
# Out:
#           Ecommunityname state countyCode communityCode  fold  population  \
# 2210          Mercedcity    CA        NaN           NaN    10       56216
# 2211       Pinevillecity    LA        NaN           NaN    10       12251
# 2212         Yucaipacity    CA        NaN           NaN    10       32824
# 2213        Beevillecity    TX        NaN           NaN    10       13547
# 2214  WestSacramentocity    CA        NaN           NaN    10       28898
#
#       householdsize  racepctblack  racePctWhite  racePctAsian      ...        \
# 2210           3.07          6.87         61.68         15.23      ...
# 2211           2.68         21.18         76.65          1.52      ...
# 2212           2.46          0.52         92.62          0.98      ...
# 2213           2.89          3.37         69.91          0.90      ...
# 2214           2.61          2.39         71.27          9.09      ...
#
#       burglaries  burglPerPop  larcenies  larcPerPop  autoTheft  \
# 2210        1376      2268.72       2563     4225.82        489
# 2211         104       860.43        574      4748.9         24
# 2212         628      1709.26        895     2435.97        179
# 2213         192      1508.01        474      3722.9         13
# 2214         791      2614.53       1458      4819.2        405
#
#       autoTheftPerPop  arsons  arsonsPerPop  ViolentCrimesPerPop  \
# 2210           806.25      34         56.06               545.75
# 2211           198.56       2         16.55                124.1
# 2212           487.19       8         21.77               353.83
# 2213            102.1       1          7.85               691.17
# 2214          1338.67      20         66.11               918.89
#
#       nonViolPerPop
# 2210        7356.84
# 2211        5824.44
# 2212         4654.2
# 2213        5340.87
# 2214         8838.5
#
# [5 rows x 147 columns]

# %%
print(df.groupby('Ecommunityname')['Ecommunityname'].count())
# Out:
# Ecommunityname
# Aberdeencity          2
# Aberdeentown          1
# Aberdeentownship      1
# Adacity               1
# Adriancity            1
# AgouraHillscity       1
# Aikencity             1
# Akroncity             1
# Alabastercity         1
# Alamedacity           1
# Alamogordocity        1
# Albanycity            4
# Albemarlecity         1
# AlbertLeacity         1
# Albioncity            1
# Albuquerquecity       1
# AlexanderCitycity     1
# Alexandriacity        2
# Algonquinvillage      1
# Alhambracity          1
# Alicecity             1
# AllenParkcity         1
# Allencity             1
# Allentowncity         1
# Alliancecity          1
# Alpenacity            1
# Alpharettacity        1
# Altoonacity           1
# Altuscity             1
# Alvincity             1
#                      ..
# Woburncity            1
# Wolcotttown           1
# Woodbridgetownship    1
# Woodburncity          1
# Woodburycity          2
# Woodhavencity         1
# Woodlandcity          1
# Woodwardcity          1
# Woonsocketcity        1
# Woostercity           1
# Worcestercity         1
# Worthingtoncity       1
# Wyandottecity         1
# Wyckofftownship       1
# Wyomingcity           1
# Xeniacity             1
# Yakimacity            1
# Yanktoncity           1
# Yarmouthtown          1
# Yeadonborough         1
# Yonkerscity           1
# YorbaLindacity        1
# Yorktownship          1
# Yorktowntown          1
# Youngstowncity        1
# Ypsilanticity         1
# YubaCitycity          1
# Yucaipacity           1
# Yukoncity             1
# Zanesvillecity        1
# Name: Ecommunityname, Length: 2018, dtype: int64

# %%
df.groupby('state')['state'].count()
# Out:
# state
# AK      3
# AL     43
# AR     25
# AZ     20
# CA    279
# CO     25
# CT     71
# DC      1
# DE      1
# FL     90
# GA     37
# IA     20
# ID      7
# IL     40
# IN     48
# KS      1
# KY     26
# LA     22
# MA    123
# MD     12
# ME     17
# MI    108
# MN     66
# MO     42
# MS     20
# NC     46
# ND      8
# NH     21
# NJ    211
# NM     10
# NV      5
# NY     46
# OH    111
# OK     36
# OR     31
# PA    101
# RI     26
# SC     28
# SD      9
# TN     35
# TX    162
# UT     24
# VA     33
# VT      4
# WA     40
# WI     60
# WV     14
# WY      7
# Name: state, dtype: int64

# %% [markdown]
# # Explore Variables
#
# - 147 features exist, both predictive features and features to be predicted
# - 2215 observations exist
# - Some features already have missing values
#
# Let's take a further analysis into some of the missing values
#
# # TODO: Find outliers and ELIMINATE THEM
# - new york city, los angelos, and chicago

# %%
for col in df.columns:
    print(col+': '+str(df[col].count()))
# Out:
# Ecommunityname: 2215
# state: 2215
# countyCode: 994
# communityCode: 991
# fold: 2215
# population: 2215
# householdsize: 2215
# racepctblack: 2215
# racePctWhite: 2215
# racePctAsian: 2215
# racePctHisp: 2215
# agePct12t21: 2215
# agePct12t29: 2215
# agePct16t24: 2215
# agePct65up: 2215
# numbUrban: 2215
# pctUrban: 2215
# medIncome: 2215
# pctWWage: 2215
# pctWFarmSelf: 2215
# pctWInvInc: 2215
# pctWSocSec: 2215
# pctWPubAsst: 2215
# pctWRetire: 2215
# medFamInc: 2215
# perCapInc: 2215
# whitePerCap: 2215
# blackPerCap: 2215
# indianPerCap: 2215
# AsianPerCap: 2215
# OtherPerCap: 2214
# HispPerCap: 2215
# NumUnderPov: 2215
# PctPopUnderPov: 2215
# PctLess9thGrade: 2215
# PctNotHSGrad: 2215
# PctBSorMore: 2215
# PctUnemployed: 2215
# PctEmploy: 2215
# PctEmplManu: 2215
# PctEmplProfServ: 2215
# PctOccupManu: 2215
# PctOccupMgmtProf: 2215
# MalePctDivorce: 2215
# MalePctNevMarr: 2215
# FemalePctDiv: 2215
# TotalPctDiv: 2215
# PersPerFam: 2215
# PctFam2Par: 2215
# PctKids2Par: 2215
# PctYoungKids2Par: 2215
# PctTeen2Par: 2215
# PctWorkMomYoungKids: 2215
# PctWorkMom: 2215
# NumKidsBornNeverMar: 2215
# PctKidsBornNeverMar: 2215
# NumImmig: 2215
# PctImmigRecent: 2215
# PctImmigRec5: 2215
# PctImmigRec8: 2215
# PctImmigRec10: 2215
# PctRecentImmig: 2215
# PctRecImmig5: 2215
# PctRecImmig8: 2215
# PctRecImmig10: 2215
# PctSpeakEnglOnly: 2215
# PctNotSpeakEnglWell: 2215
# PctLargHouseFam: 2215
# PctLargHouseOccup: 2215
# PersPerOccupHous: 2215
# PersPerOwnOccHous: 2215
# PersPerRentOccHous: 2215
# PctPersOwnOccup: 2215
# PctPersDenseHous: 2215
# PctHousLess3BR: 2215
# MedNumBR: 2215
# HousVacant: 2215
# PctHousOccup: 2215
# PctHousOwnOcc: 2215
# PctVacantBoarded: 2215
# PctVacMore6Mos: 2215
# MedYrHousBuilt: 2215
# PctHousNoPhone: 2215
# PctWOFullPlumb: 2215
# OwnOccLowQuart: 2215
# OwnOccMedVal: 2215
# OwnOccHiQuart: 2215
# OwnOccQrange: 2215
# RentLowQ: 2215
# RentMedian: 2215
# RentHighQ: 2215
# RentQrange: 2215
# MedRent: 2215
# MedRentPctHousInc: 2215
# MedOwnCostPctInc: 2215
# MedOwnCostPctIncNoMtg: 2215
# NumInShelters: 2215
# NumStreet: 2215
# PctForeignBorn: 2215
# PctBornSameState: 2215
# PctSameHouse85: 2215
# PctSameCity85: 2215
# PctSameState85: 2215
# LemasSwornFT: 343
# LemasSwFTPerPop: 343
# LemasSwFTFieldOps: 343
# LemasSwFTFieldPerPop: 343
# LemasTotalReq: 343
# LemasTotReqPerPop: 343
# PolicReqPerOffic: 343
# PolicPerPop: 343
# RacialMatchCommPol: 343
# PctPolicWhite: 343
# PctPolicBlack: 343
# PctPolicHisp: 343
# PctPolicAsian: 343
# PctPolicMinor: 343
# OfficAssgnDrugUnits: 343
# NumKindsDrugsSeiz: 343
# PolicAveOTWorked: 343
# LandArea: 2215
# PopDens: 2215
# PctUsePubTrans: 2215
# PolicCars: 343
# PolicOperBudg: 343
# LemasPctPolicOnPatr: 343
# LemasGangUnitDeploy: 343
# LemasPctOfficDrugUn: 2215
# PolicBudgPerPop: 343
# murders: 2215
# murdPerPop: 2215
# rapes: 2007
# rapesPerPop: 2007
# robberies: 2214
# robbbPerPop: 2214
# assaults: 2202
# assaultPerPop: 2202
# burglaries: 2212
# burglPerPop: 2212
# larcenies: 2212
# larcPerPop: 2212
# autoTheft: 2212
# autoTheftPerPop: 2212
# arsons: 2124
# arsonsPerPop: 2124
# ViolentCrimesPerPop: 1994
# nonViolPerPop: 2118

# %%
# drop columns with less than ~25% of observations
for col in df.columns:
    if df[col].count() < 500:
        del df[col]
        
index = df[df['Ecommunityname']=='NewYorkcity'].head(1).index
df.drop(index)
index = df[df['Ecommunityname']=='Chicagocity'].head(1).index
df.drop(index)
index = df[df['Ecommunityname']=='LosAngelescity'].head(1).index
df.drop(index)
        
# ignore columns with datatype of string      
# or any column with no predictive power
del df['Ecommunityname']
del df['state']
del df['countyCode']
del df['communityCode']
del df['fold']
del df['OtherPerCap']

# ignore features to predict for future reference
del df['rapes']
del df['rapesPerPop']
del df['robberies']
del df['robbbPerPop']
del df['assaults']
del df['assaultPerPop']
del df['burglaries']
del df['burglPerPop']
del df['larcenies']
del df['larcPerPop']
del df['autoTheft']
del df['autoTheftPerPop']
del df['arsons']
del df['arsonsPerPop']
del df['nonViolPerPop']
del df['murders']
del df['murdPerPop']

df.to_csv('data/processed_crimedata.csv')

# for now, we will just look at violent crimes
# drop any missing observations from y and its corresponding X
df = df[df['ViolentCrimesPerPop'].isnull() == False]
y = df['ViolentCrimesPerPop']
del df['ViolentCrimesPerPop']

print('Features remaining: '+str(len(df.columns)))
# Out:
# Features remaining: 101

# %% [markdown]
# ## Organize Feature Groups
#
# Despite eliminating a few features, there still exists more features than is
# necessary for analysis.
#
# Let's eliminate more features by first selecting the most predictive features.
#
# More feature groups will be created based on the top features, as well
# as the top features mentioned by the paper.

# %%
all_features = df.columns

# %%
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import chi2

# feature extraction via chi squared test
test = SelectKBest(score_func=chi2, k=30)
fit = test.fit(df, y)

# organize top features into a list
d = dict(zip(df.columns, fit.scores_))
top_features = sorted(d, key=d.__getitem__, reverse=True)[0:30]
print(top_features)
# Out:
# ['numbUrban', 'population', 'NumImmig', 'NumUnderPov', 'NumKidsBornNeverMar', 'OwnOccHiQuart', 'OwnOccMedVal', 'OwnOccLowQuart', 'OwnOccQrange', 'HousVacant', 'indianPerCap', 'blackPerCap', 'AsianPerCap', 'medIncome', 'medFamInc', 'NumInShelters', 'NumStreet', 'HispPerCap', 'PopDens', 'perCapInc', 'whitePerCap', 'LandArea', 'RentHighQ', 'RentMedian', 'RentLowQ', 'MedRent', 'RentQrange', 'pctUrban', 'racePctHisp', 'racepctblack']

# %%
df[top_features].describe(include='all')
# Out:
#           numbUrban    population      NumImmig   NumUnderPov  \
# count  1.994000e+03  1.994000e+03  1.994000e+03  1.994000e+03
# mean   4.667176e+04  5.225143e+04  6.313566e+03  7.398380e+03
# std    2.031508e+05  2.021475e+05  5.708065e+04  3.793092e+04
# min    0.000000e+00  1.000500e+04  2.000000e+01  7.800000e+01
# 25%    0.000000e+00  1.435925e+04  4.070000e+02  9.362500e+02
# 50%    1.734850e+04  2.268100e+04  1.039500e+03  2.217500e+03
# 75%    4.193150e+04  4.315375e+04  3.389250e+03  5.097500e+03
# max    7.322564e+06  7.322564e+06  2.082931e+06  1.384994e+06
#
#        NumKidsBornNeverMar  OwnOccHiQuart   OwnOccMedVal  OwnOccLowQuart  \
# count          1994.000000    1994.000000    1994.000000     1994.000000
# mean           2041.450351  149007.191575  116102.414243    91116.201103
# std           14021.347701  101124.665073   83971.437925    68581.851565
# min               0.000000   36700.000000   26600.000000    15700.000000
# 25%             146.250000   74800.000000   56700.000000    41800.000000
# 50%             361.000000  109500.000000   84600.000000    65900.000000
# 75%            1070.250000  192850.000000  156250.000000   126800.000000
# max          527557.000000  500001.000000  500001.000000   500001.000000
#
#         OwnOccQrange     HousVacant      ...        whitePerCap     LandArea  \
# count    1994.000000    1994.000000      ...        1994.000000  1994.000000
# mean    57890.990471    1733.037111      ...       16535.021063    27.962889
# std     39527.424643    5890.906929      ...        6311.111286   114.827752
# min         0.000000      36.000000      ...        5472.000000     0.900000
# 25%     32925.000000     310.000000      ...       12596.000000     7.400000
# 50%     44250.000000     582.500000      ...       15027.500000    13.700000
# 75%     67475.000000    1280.500000      ...       18609.750000    25.775000
# max    331000.000000  172768.000000      ...       68850.000000  3569.800000
#
#          RentHighQ   RentMedian     RentLowQ      MedRent   RentQrange  \
# count  1994.000000  1994.000000  1994.000000  1994.000000  1994.000000
# mean    528.368104   428.447844   328.062688   502.730191   200.305416
# std     203.360888   174.548134   146.381388   172.522021    86.724596
# min     182.000000   120.000000    99.000000   192.000000     0.000000
# 25%     361.250000   286.000000   210.000000   363.000000   139.000000
# 50%     484.000000   394.000000   305.000000   467.000000   173.000000
# 75%     667.750000   547.750000   420.000000   621.000000   241.000000
# max    1001.000000  1001.000000  1001.000000  1001.000000   803.000000
#
#           pctUrban  racePctHisp  racepctblack
# count  1994.000000  1994.000000   1994.000000
# mean     69.621545     8.481610      9.509694
# std      44.478865    15.208788     14.101979
# min       0.000000     0.120000      0.000000
# 25%       0.000000     0.920000      0.940000
# 50%     100.000000     2.340000      3.150000
# 75%     100.000000     8.610000     11.965000
# max     100.000000    95.290000     96.670000
#
# [8 rows x 30 columns]

# %%
# exclude potentially discriminating features
biased_features = ['NumImmig','indianPerCap','blackPerCap','AsianPerCap',
                   'HispPerCap','whitePerCap','racePctHisp','racepctblack']
unbiased_top_features = [feature for feature in top_features if feature not in biased_features]

print(unbiased_top_features)
# Out:
# ['numbUrban', 'population', 'NumUnderPov', 'NumKidsBornNeverMar', 'OwnOccHiQuart', 'OwnOccMedVal', 'OwnOccLowQuart', 'OwnOccQrange', 'HousVacant', 'medIncome', 'medFamInc', 'NumInShelters', 'NumStreet', 'PopDens', 'perCapInc', 'LandArea', 'RentHighQ', 'RentMedian', 'RentLowQ', 'MedRent', 'RentQrange', 'pctUrban']

# %%
df[unbiased_top_features].describe(include='all')
# Out:
#           numbUrban    population   NumUnderPov  NumKidsBornNeverMar  \
# count  1.994000e+03  1.994000e+03  1.994000e+03          1994.000000
# mean   4.667176e+04  5.225143e+04  7.398380e+03          2041.450351
# std    2.031508e+05  2.021475e+05  3.793092e+04         14021.347701
# min    0.000000e+00  1.000500e+04  7.800000e+01             0.000000
# 25%    0.000000e+00  1.435925e+04  9.362500e+02           146.250000
# 50%    1.734850e+04  2.268100e+04  2.217500e+03           361.000000
# 75%    4.193150e+04  4.315375e+04  5.097500e+03          1070.250000
# max    7.322564e+06  7.322564e+06  1.384994e+06        527557.000000
#
#        OwnOccHiQuart   OwnOccMedVal  OwnOccLowQuart   OwnOccQrange  \
# count    1994.000000    1994.000000     1994.000000    1994.000000
# mean   149007.191575  116102.414243    91116.201103   57890.990471
# std    101124.665073   83971.437925    68581.851565   39527.424643
# min     36700.000000   26600.000000    15700.000000       0.000000
# 25%     74800.000000   56700.000000    41800.000000   32925.000000
# 50%    109500.000000   84600.000000    65900.000000   44250.000000
# 75%    192850.000000  156250.000000   126800.000000   67475.000000
# max    500001.000000  500001.000000   500001.000000  331000.000000
#
#           HousVacant      medIncome     ...          NumStreet       PopDens  \
# count    1994.000000    1994.000000     ...        1994.000000   1994.000000
# mean     1733.037111   33699.327482     ...          18.712136   2789.862487
# std      5890.906929   13391.741380     ...         256.203872   2920.185784
# min        36.000000   11576.000000     ...           0.000000     10.000000
# 25%       310.000000   23597.000000     ...           0.000000   1170.825000
# 50%       582.500000   30896.000000     ...           0.000000   1996.100000
# 75%      1280.500000   41214.750000     ...           1.000000   3270.400000
# max    172768.000000  123625.000000     ...       10447.000000  44229.900000
#
#           perCapInc     LandArea    RentHighQ   RentMedian     RentLowQ  \
# count   1994.000000  1994.000000  1994.000000  1994.000000  1994.000000
# mean   15521.723170    27.962889   528.368104   428.447844   328.062688
# std     6227.115252   114.827752   203.360888   174.548134   146.381388
# min     5237.000000     0.900000   182.000000   120.000000    99.000000
# 25%    11548.250000     7.400000   361.250000   286.000000   210.000000
# 50%    13977.000000    13.700000   484.000000   394.000000   305.000000
# 75%    17774.500000    25.775000   667.750000   547.750000   420.000000
# max    63302.000000  3569.800000  1001.000000  1001.000000  1001.000000
#
#            MedRent   RentQrange     pctUrban
# count  1994.000000  1994.000000  1994.000000
# mean    502.730191   200.305416    69.621545
# std     172.522021    86.724596    44.478865
# min     192.000000     0.000000     0.000000
# 25%     363.000000   139.000000     0.000000
# 50%     467.000000   173.000000   100.000000
# 75%     621.000000   241.000000   100.000000
# max    1001.000000   803.000000   100.000000
#
# [8 rows x 22 columns]

# %%
# top features according to paper
# population, density, unemployment rate, poverty rate
paper_features = ['population','PopDens','PctUnemployed','PctPopUnderPov']
print(paper_features)
# Out:
# ['population', 'PopDens', 'PctUnemployed', 'PctPopUnderPov']

# %%
df[paper_features].describe(include='all')
# Out:
#          population       PopDens  PctUnemployed  PctPopUnderPov
# count  1.994000e+03   1994.000000    1994.000000     1994.000000
# mean   5.225143e+04   2789.862487       6.023862       11.795933
# std    2.021475e+05   2920.185784       2.725405        8.509501
# min    1.000500e+04     10.000000       1.320000        0.640000
# 25%    1.435925e+04   1170.825000       4.090000        4.692500
# 50%    2.268100e+04   1996.100000       5.485000        9.650000
# 75%    4.315375e+04   3270.400000       7.430000       17.077500
# max    7.322564e+06  44229.900000      23.830000       48.820000

# %% [markdown]
# # Explore Distributions of Features
#
# - can be helpful to determine whether scaling or normalization is crucial to final output
# - technical bias could emerge as the result of not paying attention to the distribution of variables

# %%
fig, ax = plt.subplots(len(paper_features))
for index, col in enumerate(paper_features):
    data = pd.Series(df[col])
    ax[index].hist(data, bins=25)
    ax[index].set_title(str(col)+' distribution')
fig.tight_layout()
plt.show()

# %%
fig, ax = plt.subplots(len(biased_features))
for index, col in enumerate(biased_features):
    data = pd.Series(df[col])
    ax[index].hist(data, bins=25)
    ax[index].set_title(str(col)+' distribution')
fig.tight_layout()
plt.subplots_adjust(hspace=4)
plt.show()

# %%
features_of_interest = ['population','NumImmig','indianPerCap','racePctHisp']

fig, ax = plt.subplots(2,2)
for index, col in enumerate(features_of_interest):
    if index < 2:
        row = 0
    else:
        row = 1
    data = pd.Series(df[col])
    ax[index%2,row].boxplot(data, showfliers=False)
    ax[index%2,row].set_title(str(col)+' distribution')
fig.tight_layout()
plt.show()

# %% [markdown]
# - features of interest or population, indians per capita, number of immigrants, and percentage of hispanics had outliers which skewed their distributions
# - features have varying length of min's and max's
# - it may be advantageous to scale features

# %% [markdown]
# # Prediction vs Bias
# - Using the feature groups, we can explore how accuracy can vary
# from one group of features to the next
# - Considering some feature groups have more biased features than others,
# we can determine how acccuracy varies with bias
#
# ## Method 1
# - Use feature groups selected via chi-squared tests and protected classes
# - Downside: Some features may be highly correlated with biased features

# %%
feature_groups = {'all_features':all_features,'top_features':top_features,'unbiased_top_features':unbiased_top_features,
                 'paper_features':paper_features}

# %%
from sklearn.model_selection import cross_val_score
from sklearn import preprocessing
from sklearn import linear_model

lm = linear_model.LinearRegression()
lm_accuracies = []

print('   Linear Model   ')
print('------------------')

for name, feature_group in feature_groups.items():
    X = preprocessing.normalize(df[feature_group])
    print(name)
    scores = cross_val_score(lm, X, y, cv=5)
    print('  Acc: '+str(scores.mean()))
    lm_accuracies.append(scores.mean())
# Out:
#    Linear Model
# ------------------
# all_features
#   Acc: 0.5934305448872307
# top_features
#   Acc: 0.5689052636728599
# unbiased_top_features
#   Acc: 0.5225119401626032
# paper_features
#   Acc: 0.05503070182134458

# %%
import matplotlib.pyplot as plt; plt.rcdefaults()
import numpy as np
import matplotlib.pyplot as plt
 
features = ('all_features', 'top_features', 'unbiased_top_features', 'paper_features')
y_pos = np.arange(len(features))
 
plt.bar(y_pos, lm_accuracies, align='center', alpha=0.5)
plt.xticks(y_pos, features)
plt.ylabel('Accuracy')
plt.title('Linear Model Accuracies')
plt.xticks(rotation=30)
 
plt.show()

# %%
from sklearn.model_selection import cross_val_score
from sklearn import preprocessing
from sklearn import svm
import warnings
warnings.filterwarnings('ignore')

svm = svm.LinearSVR()
svm_accuracies = []

print('   Support Vector Machine   ')
print('----------------------------')

for name, feature_group in feature_groups.items():
    X = df[feature_group]
    print(name)
    scores = cross_val_score(svm, X, y, cv=5)
    print('  Mse: '+str(abs(scores).mean()))
    svm_accuracies.append(abs(scores).mean())
# Out:
#    Support Vector Machine
# ----------------------------
# all_features
#   Mse: 23.698004594034103
# top_features
#   Mse: 2.8810239099087953
# unbiased_top_features
#   Mse: 5.2792567372131805
# paper_features
#   Mse: 1.6133052965663481

# %%
import matplotlib.pyplot as plt; plt.rcdefaults()
import numpy as np
import matplotlib.pyplot as plt
 
features = ('all_features', 'top_features', 'unbiased_top_features', 'paper_features')
y_pos = np.arange(len(features))
 
plt.bar(y_pos, svm_accuracies, align='center', alpha=0.5)
plt.xticks(y_pos, features)
plt.ylabel('MSE')
plt.title('SVM MSE')
plt.xticks(rotation=30)
 
plt.show()

# %%
y = y.astype('float')
print(y.mean())
print(y.max())
print(y.min())
print(len(y))
print(len(X))
# Out:
# 589.0789217652964
# 4877.06
# 0.0
# 1994
# 1994

# %% [markdown]
# ## Method 2
# - 1) Organize features according to their worst correlation to protected features
# - 2) Make feature groups based on a rising threshold of worst correlation
# - 3) Model and plot the accuracies of these feature groups

# %%
protected_features=['NumImmig','indianPerCap','blackPerCap','AsianPerCap',
                   'HispPerCap','whitePerCap','racePctHisp','racepctblack']
non_protected_features = [feature for feature in all_features if feature not in protected_features]

feature_correlations = {}

for col in non_protected_features:
    correlations = df[protected_features].corrwith(df[col])
    worst_correlations = max(abs(correlations))
    feature_correlations[col] = worst_correlations
    
print(feature_correlations)
# Out:
# {'population': 0.9369854402571764, 'householdsize': 0.5008924086370053, 'racePctWhite': 0.8038940358376422, 'racePctAsian': 0.2888100167912569, 'agePct12t21': 0.31784544071319115, 'agePct12t29': 0.34512254651777685, 'agePct16t24': 0.27030158474886146, 'agePct65up': 0.20332624353814535, 'numbUrban': 0.934869920449747, 'pctUrban': 0.3190949173093882, 'medIncome': 0.8398830772062763, 'pctWWage': 0.29687011096319493, 'pctWFarmSelf': 0.145079665347214, 'pctWInvInc': 0.6918041002940871, 'pctWSocSec': 0.1994945944426206, 'pctWPubAsst': 0.4962360574788377, 'pctWRetire': 0.2561413764510647, 'medFamInc': 0.8852702255747001, 'perCapInc': 0.9755816109375214, 'NumUnderPov': 0.9304930803018888, 'PctPopUnderPov': 0.5447886160002082, 'PctLess9thGrade': 0.6399915633677958, 'PctNotHSGrad': 0.5892721601639179, 'PctBSorMore': 0.7643398423430514, 'PctUnemployed': 0.5261843269816555, 'PctEmploy': 0.3789359736806175, 'PctEmplManu': 0.1802556273537191, 'PctEmplProfServ': 0.22275529580821024, 'PctOccupManu': 0.632213644713215, 'PctOccupMgmtProf': 0.8043065406123521, 'MalePctDivorce': 0.39593650688562954, 'MalePctNevMarr': 0.26331419300558107, 'FemalePctDiv': 0.42418308557278006, 'TotalPctDiv': 0.42735924254337837, 'PersPerFam': 0.6526087927761959, 'PctFam2Par': 0.6987392903438865, 'PctKids2Par': 0.730885833846359, 'PctYoungKids2Par': 0.6560016951855789, 'PctTeen2Par': 0.6892853622384187, 'PctWorkMomYoungKids': 0.2857073813436561, 'PctWorkMom': 0.41993518391496587, 'NumKidsBornNeverMar': 0.915323633448696, 'PctKidsBornNeverMar': 0.8045244734195621, 'PctImmigRecent': 0.17802343156684786, 'PctImmigRec5': 0.20939423596388343, 'PctImmigRec8': 0.2190788338382307, 'PctImmigRec10': 0.2431958358145868, 'PctRecentImmig': 0.6091294975833258, 'PctRecImmig5': 0.6395984947760567, 'PctRecImmig8': 0.6465359261697942, 'PctRecImmig10': 0.668570756117917, 'PctSpeakEnglOnly': 0.9142703114913973, 'PctNotSpeakEnglWell': 0.8923207074177321, 'PctLargHouseFam': 0.7590884024149795, 'PctLargHouseOccup': 0.7373522357961648, 'PersPerOccupHous': 0.5576226168358939, 'PersPerOwnOccHous': 0.47215092843920403, 'PersPerRentOccHous': 0.6664919423841337, 'PctPersOwnOccup': 0.40444642826047555, 'PctPersDenseHous': 0.8643040378965691, 'PctHousLess3BR': 0.3453916633889354, 'MedNumBR': 0.3030794840222849, 'HousVacant': 0.7837527464296948, 'PctHousOccup': 0.1859838919079723, 'PctHousOwnOcc': 0.3701373548097218, 'PctVacantBoarded': 0.4750894888988925, 'PctVacMore6Mos': 0.17113448486477212, 'MedYrHousBuilt': 0.08891917395998726, 'PctHousNoPhone': 0.5227136347362776, 'PctWOFullPlumb': 0.4285208995832078, 'OwnOccLowQuart': 0.7862569193990757, 'OwnOccMedVal': 0.8011680393139706, 'OwnOccHiQuart': 0.812479948523399, 'OwnOccQrange': 0.7144105033218408, 'RentLowQ': 0.6838648488762323, 'RentMedian': 0.7402504484762601, 'RentHighQ': 0.7315898002127953, 'RentQrange': 0.5612210085517044, 'MedRent': 0.7285148936057154, 'MedRentPctHousInc': 0.26945343490480045, 'MedOwnCostPctInc': 0.3148687973028761, 'MedOwnCostPctIncNoMtg': 0.21705063048305295, 'NumInShelters': 0.888893062057195, 'NumStreet': 0.935250548271478, 'PctForeignBorn': 0.6912159301449885, 'PctBornSameState': 0.31143194075273933, 'PctSameHouse85': 0.23043409639578508, 'PctSameCity85': 0.12665483556811993, 'PctSameState85': 0.10868759312633923, 'LandArea': 0.1232481476954661, 'PopDens': 0.36858894664666464, 'PctUsePubTrans': 0.31734107669280687, 'LemasPctOfficDrugUn': 0.24596832670381716}

# %%
features_correlation_thresholds = {}

for x in range(2,20):
    x = x*5/100
    features_correlation_thresholds[x] = [col for col in feature_correlations\
           if feature_correlations[col] < x]
    print(x)
    print(features_correlation_thresholds[x])
# Out:
# 0.1
# ['MedYrHousBuilt']
# 0.15
# ['pctWFarmSelf', 'MedYrHousBuilt', 'PctSameCity85', 'PctSameState85', 'LandArea']
# 0.2
# ['pctWFarmSelf', 'pctWSocSec', 'PctEmplManu', 'PctImmigRecent', 'PctHousOccup', 'PctVacMore6Mos', 'MedYrHousBuilt', 'PctSameCity85', 'PctSameState85', 'LandArea']
# 0.25
# ['agePct65up', 'pctWFarmSelf', 'pctWSocSec', 'PctEmplManu', 'PctEmplProfServ', 'PctImmigRecent', 'PctImmigRec5', 'PctImmigRec8', 'PctImmigRec10', 'PctHousOccup', 'PctVacMore6Mos', 'MedYrHousBuilt', 'MedOwnCostPctIncNoMtg', 'PctSameHouse85', 'PctSameCity85', 'PctSameState85', 'LandArea', 'LemasPctOfficDrugUn']
# 0.3
# ['racePctAsian', 'agePct16t24', 'agePct65up', 'pctWWage', 'pctWFarmSelf', 'pctWSocSec', 'pctWRetire', 'PctEmplManu', 'PctEmplProfServ', 'MalePctNevMarr', 'PctWorkMomYoungKids', 'PctImmigRecent', 'PctImmigRec5', 'PctImmigRec8', 'PctImmigRec10', 'PctHousOccup', 'PctVacMore6Mos', 'MedYrHousBuilt', 'MedRentPctHousInc', 'MedOwnCostPctIncNoMtg', 'PctSameHouse85', 'PctSameCity85', 'PctSameState85', 'LandArea', 'LemasPctOfficDrugUn']
# 0.35
# ['racePctAsian', 'agePct12t21', 'agePct12t29', 'agePct16t24', 'agePct65up', 'pctUrban', 'pctWWage', 'pctWFarmSelf', 'pctWSocSec', 'pctWRetire', 'PctEmplManu', 'PctEmplProfServ', 'MalePctNevMarr', 'PctWorkMomYoungKids', 'PctImmigRecent', 'PctImmigRec5', 'PctImmigRec8', 'PctImmigRec10', 'PctHousLess3BR', 'MedNumBR', 'PctHousOccup', 'PctVacMore6Mos', 'MedYrHousBuilt', 'MedRentPctHousInc', 'MedOwnCostPctInc', 'MedOwnCostPctIncNoMtg', 'PctBornSameState', 'PctSameHouse85', 'PctSameCity85', 'PctSameState85', 'LandArea', 'PctUsePubTrans', 'LemasPctOfficDrugUn']
# 0.4
# ['racePctAsian', 'agePct12t21', 'agePct12t29', 'agePct16t24', 'agePct65up', 'pctUrban', 'pctWWage', 'pctWFarmSelf', 'pctWSocSec', 'pctWRetire', 'PctEmploy', 'PctEmplManu', 'PctEmplProfServ', 'MalePctDivorce', 'MalePctNevMarr', 'PctWorkMomYoungKids', 'PctImmigRecent', 'PctImmigRec5', 'PctImmigRec8', 'PctImmigRec10', 'PctHousLess3BR', 'MedNumBR', 'PctHousOccup', 'PctHousOwnOcc', 'PctVacMore6Mos', 'MedYrHousBuilt', 'MedRentPctHousInc', 'MedOwnCostPctInc', 'MedOwnCostPctIncNoMtg', 'PctBornSameState', 'PctSameHouse85', 'PctSameCity85', 'PctSameState85', 'LandArea', 'PopDens', 'PctUsePubTrans', 'LemasPctOfficDrugUn']
# 0.45
# ['racePctAsian', 'agePct12t21', 'agePct12t29', 'agePct16t24', 'agePct65up', 'pctUrban', 'pctWWage', 'pctWFarmSelf', 'pctWSocSec', 'pctWRetire', 'PctEmploy', 'PctEmplManu', 'PctEmplProfServ', 'MalePctDivorce', 'MalePctNevMarr', 'FemalePctDiv', 'TotalPctDiv', 'PctWorkMomYoungKids', 'PctWorkMom', 'PctImmigRecent', 'PctImmigRec5', 'PctImmigRec8', 'PctImmigRec10', 'PctPersOwnOccup', 'PctHousLess3BR', 'MedNumBR', 'PctHousOccup', 'PctHousOwnOcc', 'PctVacMore6Mos', 'MedYrHousBuilt', 'PctWOFullPlumb', 'MedRentPctHousInc', 'MedOwnCostPctInc', 'MedOwnCostPctIncNoMtg', 'PctBornSameState', 'PctSameHouse85', 'PctSameCity85', 'PctSameState85', 'LandArea', 'PopDens', 'PctUsePubTrans', 'LemasPctOfficDrugUn']
# 0.5
# ['racePctAsian', 'agePct12t21', 'agePct12t29', 'agePct16t24', 'agePct65up', 'pctUrban', 'pctWWage', 'pctWFarmSelf', 'pctWSocSec', 'pctWPubAsst', 'pctWRetire', 'PctEmploy', 'PctEmplManu', 'PctEmplProfServ', 'MalePctDivorce', 'MalePctNevMarr', 'FemalePctDiv', 'TotalPctDiv', 'PctWorkMomYoungKids', 'PctWorkMom', 'PctImmigRecent', 'PctImmigRec5', 'PctImmigRec8', 'PctImmigRec10', 'PersPerOwnOccHous', 'PctPersOwnOccup', 'PctHousLess3BR', 'MedNumBR', 'PctHousOccup', 'PctHousOwnOcc', 'PctVacantBoarded', 'PctVacMore6Mos', 'MedYrHousBuilt', 'PctWOFullPlumb', 'MedRentPctHousInc', 'MedOwnCostPctInc', 'MedOwnCostPctIncNoMtg', 'PctBornSameState', 'PctSameHouse85', 'PctSameCity85', 'PctSameState85', 'LandArea', 'PopDens', 'PctUsePubTrans', 'LemasPctOfficDrugUn']
# 0.55
# ['householdsize', 'racePctAsian', 'agePct12t21', 'agePct12t29', 'agePct16t24', 'agePct65up', 'pctUrban', 'pctWWage', 'pctWFarmSelf', 'pctWSocSec', 'pctWPubAsst', 'pctWRetire', 'PctPopUnderPov', 'PctUnemployed', 'PctEmploy', 'PctEmplManu', 'PctEmplProfServ', 'MalePctDivorce', 'MalePctNevMarr', 'FemalePctDiv', 'TotalPctDiv', 'PctWorkMomYoungKids', 'PctWorkMom', 'PctImmigRecent', 'PctImmigRec5', 'PctImmigRec8', 'PctImmigRec10', 'PersPerOwnOccHous', 'PctPersOwnOccup', 'PctHousLess3BR', 'MedNumBR', 'PctHousOccup', 'PctHousOwnOcc', 'PctVacantBoarded', 'PctVacMore6Mos', 'MedYrHousBuilt', 'PctHousNoPhone', 'PctWOFullPlumb', 'MedRentPctHousInc', 'MedOwnCostPctInc', 'MedOwnCostPctIncNoMtg', 'PctBornSameState', 'PctSameHouse85', 'PctSameCity85', 'PctSameState85', 'LandArea', 'PopDens', 'PctUsePubTrans', 'LemasPctOfficDrugUn']
# 0.6
# ['householdsize', 'racePctAsian', 'agePct12t21', 'agePct12t29', 'agePct16t24', 'agePct65up', 'pctUrban', 'pctWWage', 'pctWFarmSelf', 'pctWSocSec', 'pctWPubAsst', 'pctWRetire', 'PctPopUnderPov', 'PctNotHSGrad', 'PctUnemployed', 'PctEmploy', 'PctEmplManu', 'PctEmplProfServ', 'MalePctDivorce', 'MalePctNevMarr', 'FemalePctDiv', 'TotalPctDiv', 'PctWorkMomYoungKids', 'PctWorkMom', 'PctImmigRecent', 'PctImmigRec5', 'PctImmigRec8', 'PctImmigRec10', 'PersPerOccupHous', 'PersPerOwnOccHous', 'PctPersOwnOccup', 'PctHousLess3BR', 'MedNumBR', 'PctHousOccup', 'PctHousOwnOcc', 'PctVacantBoarded', 'PctVacMore6Mos', 'MedYrHousBuilt', 'PctHousNoPhone', 'PctWOFullPlumb', 'RentQrange', 'MedRentPctHousInc', 'MedOwnCostPctInc', 'MedOwnCostPctIncNoMtg', 'PctBornSameState', 'PctSameHouse85', 'PctSameCity85', 'PctSameState85', 'LandArea', 'PopDens', 'PctUsePubTrans', 'LemasPctOfficDrugUn']
# 0.65
# ['householdsize', 'racePctAsian', 'agePct12t21', 'agePct12t29', 'agePct16t24', 'agePct65up', 'pctUrban', 'pctWWage', 'pctWFarmSelf', 'pctWSocSec', 'pctWPubAsst', 'pctWRetire', 'PctPopUnderPov', 'PctLess9thGrade', 'PctNotHSGrad', 'PctUnemployed', 'PctEmploy', 'PctEmplManu', 'PctEmplProfServ', 'PctOccupManu', 'MalePctDivorce', 'MalePctNevMarr', 'FemalePctDiv', 'TotalPctDiv', 'PctWorkMomYoungKids', 'PctWorkMom', 'PctImmigRecent', 'PctImmigRec5', 'PctImmigRec8', 'PctImmigRec10', 'PctRecentImmig', 'PctRecImmig5', 'PctRecImmig8', 'PersPerOccupHous', 'PersPerOwnOccHous', 'PctPersOwnOccup', 'PctHousLess3BR', 'MedNumBR', 'PctHousOccup', 'PctHousOwnOcc', 'PctVacantBoarded', 'PctVacMore6Mos', 'MedYrHousBuilt', 'PctHousNoPhone', 'PctWOFullPlumb', 'RentQrange', 'MedRentPctHousInc', 'MedOwnCostPctInc', 'MedOwnCostPctIncNoMtg', 'PctBornSameState', 'PctSameHouse85', 'PctSameCity85', 'PctSameState85', 'LandArea', 'PopDens', 'PctUsePubTrans', 'LemasPctOfficDrugUn']
# 0.7
# ['householdsize', 'racePctAsian', 'agePct12t21', 'agePct12t29', 'agePct16t24', 'agePct65up', 'pctUrban', 'pctWWage', 'pctWFarmSelf', 'pctWInvInc', 'pctWSocSec', 'pctWPubAsst', 'pctWRetire', 'PctPopUnderPov', 'PctLess9thGrade', 'PctNotHSGrad', 'PctUnemployed', 'PctEmploy', 'PctEmplManu', 'PctEmplProfServ', 'PctOccupManu', 'MalePctDivorce', 'MalePctNevMarr', 'FemalePctDiv', 'TotalPctDiv', 'PersPerFam', 'PctFam2Par', 'PctYoungKids2Par', 'PctTeen2Par', 'PctWorkMomYoungKids', 'PctWorkMom', 'PctImmigRecent', 'PctImmigRec5', 'PctImmigRec8', 'PctImmigRec10', 'PctRecentImmig', 'PctRecImmig5', 'PctRecImmig8', 'PctRecImmig10', 'PersPerOccupHous', 'PersPerOwnOccHous', 'PersPerRentOccHous', 'PctPersOwnOccup', 'PctHousLess3BR', 'MedNumBR', 'PctHousOccup', 'PctHousOwnOcc', 'PctVacantBoarded', 'PctVacMore6Mos', 'MedYrHousBuilt', 'PctHousNoPhone', 'PctWOFullPlumb', 'RentLowQ', 'RentQrange', 'MedRentPctHousInc', 'MedOwnCostPctInc', 'MedOwnCostPctIncNoMtg', 'PctForeignBorn', 'PctBornSameState', 'PctSameHouse85', 'PctSameCity85', 'PctSameState85', 'LandArea', 'PopDens', 'PctUsePubTrans', 'LemasPctOfficDrugUn']
# 0.75
# ['householdsize', 'racePctAsian', 'agePct12t21', 'agePct12t29', 'agePct16t24', 'agePct65up', 'pctUrban', 'pctWWage', 'pctWFarmSelf', 'pctWInvInc', 'pctWSocSec', 'pctWPubAsst', 'pctWRetire', 'PctPopUnderPov', 'PctLess9thGrade', 'PctNotHSGrad', 'PctUnemployed', 'PctEmploy', 'PctEmplManu', 'PctEmplProfServ', 'PctOccupManu', 'MalePctDivorce', 'MalePctNevMarr', 'FemalePctDiv', 'TotalPctDiv', 'PersPerFam', 'PctFam2Par', 'PctKids2Par', 'PctYoungKids2Par', 'PctTeen2Par', 'PctWorkMomYoungKids', 'PctWorkMom', 'PctImmigRecent', 'PctImmigRec5', 'PctImmigRec8', 'PctImmigRec10', 'PctRecentImmig', 'PctRecImmig5', 'PctRecImmig8', 'PctRecImmig10', 'PctLargHouseOccup', 'PersPerOccupHous', 'PersPerOwnOccHous', 'PersPerRentOccHous', 'PctPersOwnOccup', 'PctHousLess3BR', 'MedNumBR', 'PctHousOccup', 'PctHousOwnOcc', 'PctVacantBoarded', 'PctVacMore6Mos', 'MedYrHousBuilt', 'PctHousNoPhone', 'PctWOFullPlumb', 'OwnOccQrange', 'RentLowQ', 'RentMedian', 'RentHighQ', 'RentQrange', 'MedRent', 'MedRentPctHousInc', 'MedOwnCostPctInc', 'MedOwnCostPctIncNoMtg', 'PctForeignBorn', 'PctBornSameState', 'PctSameHouse85', 'PctSameCity85', 'PctSameState85', 'LandArea', 'PopDens', 'PctUsePubTrans', 'LemasPctOfficDrugUn']
# 0.8
# ['householdsize', 'racePctAsian', 'agePct12t21', 'agePct12t29', 'agePct16t24', 'agePct65up', 'pctUrban', 'pctWWage', 'pctWFarmSelf', 'pctWInvInc', 'pctWSocSec', 'pctWPubAsst', 'pctWRetire', 'PctPopUnderPov', 'PctLess9thGrade', 'PctNotHSGrad', 'PctBSorMore', 'PctUnemployed', 'PctEmploy', 'PctEmplManu', 'PctEmplProfServ', 'PctOccupManu', 'MalePctDivorce', 'MalePctNevMarr', 'FemalePctDiv', 'TotalPctDiv', 'PersPerFam', 'PctFam2Par', 'PctKids2Par', 'PctYoungKids2Par', 'PctTeen2Par', 'PctWorkMomYoungKids', 'PctWorkMom', 'PctImmigRecent', 'PctImmigRec5', 'PctImmigRec8', 'PctImmigRec10', 'PctRecentImmig', 'PctRecImmig5', 'PctRecImmig8', 'PctRecImmig10', 'PctLargHouseFam', 'PctLargHouseOccup', 'PersPerOccupHous', 'PersPerOwnOccHous', 'PersPerRentOccHous', 'PctPersOwnOccup', 'PctHousLess3BR', 'MedNumBR', 'HousVacant', 'PctHousOccup', 'PctHousOwnOcc', 'PctVacantBoarded', 'PctVacMore6Mos', 'MedYrHousBuilt', 'PctHousNoPhone', 'PctWOFullPlumb', 'OwnOccLowQuart', 'OwnOccQrange', 'RentLowQ', 'RentMedian', 'RentHighQ', 'RentQrange', 'MedRent', 'MedRentPctHousInc', 'MedOwnCostPctInc', 'MedOwnCostPctIncNoMtg', 'PctForeignBorn', 'PctBornSameState', 'PctSameHouse85', 'PctSameCity85', 'PctSameState85', 'LandArea', 'PopDens', 'PctUsePubTrans', 'LemasPctOfficDrugUn']
# 0.85
# ['householdsize', 'racePctWhite', 'racePctAsian', 'agePct12t21', 'agePct12t29', 'agePct16t24', 'agePct65up', 'pctUrban', 'medIncome', 'pctWWage', 'pctWFarmSelf', 'pctWInvInc', 'pctWSocSec', 'pctWPubAsst', 'pctWRetire', 'PctPopUnderPov', 'PctLess9thGrade', 'PctNotHSGrad', 'PctBSorMore', 'PctUnemployed', 'PctEmploy', 'PctEmplManu', 'PctEmplProfServ', 'PctOccupManu', 'PctOccupMgmtProf', 'MalePctDivorce', 'MalePctNevMarr', 'FemalePctDiv', 'TotalPctDiv', 'PersPerFam', 'PctFam2Par', 'PctKids2Par', 'PctYoungKids2Par', 'PctTeen2Par', 'PctWorkMomYoungKids', 'PctWorkMom', 'PctKidsBornNeverMar', 'PctImmigRecent', 'PctImmigRec5', 'PctImmigRec8', 'PctImmigRec10', 'PctRecentImmig', 'PctRecImmig5', 'PctRecImmig8', 'PctRecImmig10', 'PctLargHouseFam', 'PctLargHouseOccup', 'PersPerOccupHous', 'PersPerOwnOccHous', 'PersPerRentOccHous', 'PctPersOwnOccup', 'PctHousLess3BR', 'MedNumBR', 'HousVacant', 'PctHousOccup', 'PctHousOwnOcc', 'PctVacantBoarded', 'PctVacMore6Mos', 'MedYrHousBuilt', 'PctHousNoPhone', 'PctWOFullPlumb', 'OwnOccLowQuart', 'OwnOccMedVal', 'OwnOccHiQuart', 'OwnOccQrange', 'RentLowQ', 'RentMedian', 'RentHighQ', 'RentQrange', 'MedRent', 'MedRentPctHousInc', 'MedOwnCostPctInc', 'MedOwnCostPctIncNoMtg', 'PctForeignBorn', 'PctBornSameState', 'PctSameHouse85', 'PctSameCity85', 'PctSameState85', 'LandArea', 'PopDens', 'PctUsePubTrans', 'LemasPctOfficDrugUn']
# 0.9
# ['householdsize', 'racePctWhite', 'racePctAsian', 'agePct12t21', 'agePct12t29', 'agePct16t24', 'agePct65up', 'pctUrban', 'medIncome', 'pctWWage', 'pctWFarmSelf', 'pctWInvInc', 'pctWSocSec', 'pctWPubAsst', 'pctWRetire', 'medFamInc', 'PctPopUnderPov', 'PctLess9thGrade', 'PctNotHSGrad', 'PctBSorMore', 'PctUnemployed', 'PctEmploy', 'PctEmplManu', 'PctEmplProfServ', 'PctOccupManu', 'PctOccupMgmtProf', 'MalePctDivorce', 'MalePctNevMarr', 'FemalePctDiv', 'TotalPctDiv', 'PersPerFam', 'PctFam2Par', 'PctKids2Par', 'PctYoungKids2Par', 'PctTeen2Par', 'PctWorkMomYoungKids', 'PctWorkMom', 'PctKidsBornNeverMar', 'PctImmigRecent', 'PctImmigRec5', 'PctImmigRec8', 'PctImmigRec10', 'PctRecentImmig', 'PctRecImmig5', 'PctRecImmig8', 'PctRecImmig10', 'PctNotSpeakEnglWell', 'PctLargHouseFam', 'PctLargHouseOccup', 'PersPerOccupHous', 'PersPerOwnOccHous', 'PersPerRentOccHous', 'PctPersOwnOccup', 'PctPersDenseHous', 'PctHousLess3BR', 'MedNumBR', 'HousVacant', 'PctHousOccup', 'PctHousOwnOcc', 'PctVacantBoarded', 'PctVacMore6Mos', 'MedYrHousBuilt', 'PctHousNoPhone', 'PctWOFullPlumb', 'OwnOccLowQuart', 'OwnOccMedVal', 'OwnOccHiQuart', 'OwnOccQrange', 'RentLowQ', 'RentMedian', 'RentHighQ', 'RentQrange', 'MedRent', 'MedRentPctHousInc', 'MedOwnCostPctInc', 'MedOwnCostPctIncNoMtg', 'NumInShelters', 'PctForeignBorn', 'PctBornSameState', 'PctSameHouse85', 'PctSameCity85', 'PctSameState85', 'LandArea', 'PopDens', 'PctUsePubTrans', 'LemasPctOfficDrugUn']
# 0.95
# ['population', 'householdsize', 'racePctWhite', 'racePctAsian', 'agePct12t21', 'agePct12t29', 'agePct16t24', 'agePct65up', 'numbUrban', 'pctUrban', 'medIncome', 'pctWWage', 'pctWFarmSelf', 'pctWInvInc', 'pctWSocSec', 'pctWPubAsst', 'pctWRetire', 'medFamInc', 'NumUnderPov', 'PctPopUnderPov', 'PctLess9thGrade', 'PctNotHSGrad', 'PctBSorMore', 'PctUnemployed', 'PctEmploy', 'PctEmplManu', 'PctEmplProfServ', 'PctOccupManu', 'PctOccupMgmtProf', 'MalePctDivorce', 'MalePctNevMarr', 'FemalePctDiv', 'TotalPctDiv', 'PersPerFam', 'PctFam2Par', 'PctKids2Par', 'PctYoungKids2Par', 'PctTeen2Par', 'PctWorkMomYoungKids', 'PctWorkMom', 'NumKidsBornNeverMar', 'PctKidsBornNeverMar', 'PctImmigRecent', 'PctImmigRec5', 'PctImmigRec8', 'PctImmigRec10', 'PctRecentImmig', 'PctRecImmig5', 'PctRecImmig8', 'PctRecImmig10', 'PctSpeakEnglOnly', 'PctNotSpeakEnglWell', 'PctLargHouseFam', 'PctLargHouseOccup', 'PersPerOccupHous', 'PersPerOwnOccHous', 'PersPerRentOccHous', 'PctPersOwnOccup', 'PctPersDenseHous', 'PctHousLess3BR', 'MedNumBR', 'HousVacant', 'PctHousOccup', 'PctHousOwnOcc', 'PctVacantBoarded', 'PctVacMore6Mos', 'MedYrHousBuilt', 'PctHousNoPhone', 'PctWOFullPlumb', 'OwnOccLowQuart', 'OwnOccMedVal', 'OwnOccHiQuart', 'OwnOccQrange', 'RentLowQ', 'RentMedian', 'RentHighQ', 'RentQrange', 'MedRent', 'MedRentPctHousInc', 'MedOwnCostPctInc', 'MedOwnCostPctIncNoMtg', 'NumInShelters', 'NumStreet', 'PctForeignBorn', 'PctBornSameState', 'PctSameHouse85', 'PctSameCity85', 'PctSameState85', 'LandArea', 'PopDens', 'PctUsePubTrans', 'LemasPctOfficDrugUn']

# %%
from sklearn.model_selection import cross_val_score
from sklearn import preprocessing
from sklearn import linear_model

lm = linear_model.LinearRegression()
lm_accuracies = {}

for name, feature_group in features_correlation_thresholds.items():
    X = preprocessing.normalize(df[feature_group])
    scores = cross_val_score(lm, X, y, cv=5)
    lm_accuracies[name] = scores.mean()
    
bias_accuracy_tradeoff = {'Correlation to biased features':list(lm_accuracies.keys()),
                          'Accuracy of feature group':list(lm_accuracies.values())}
bias_accuracy_tradeoff = pd.DataFrame.from_dict(bias_accuracy_tradeoff)
bias_accuracy_tradeoff
# Out:
#     Correlation to biased features  Accuracy of feature group
# 0                             0.10                  -0.003888
# 1                             0.15                   0.033121
# 2                             0.20                   0.141307
# 3                             0.25                   0.319614
# 4                             0.30                   0.458895
# 5                             0.35                   0.478336
# 6                             0.40                   0.407856
# 7                             0.45                   0.437231
# 8                             0.50                   0.459815
# 9                             0.55                   0.463071
# 10                            0.60                   0.465351
# 11                            0.65                   0.481916
# 12                            0.70                   0.519510
# 13                            0.75                   0.330327
# 14                            0.80                   0.553736
# 15                            0.85                   0.554979
# 16                            0.90                   0.518611
# 17                            0.95                   0.584145

# %%
import statsmodels.api as sm

correlations = bias_accuracy_tradeoff['Correlation to biased features']

bias_accuracy_tradeoff['Correlation to biased features ^2'] =\
    correlations*correlations
bias_accuracy_tradeoff['Correlation to biased features ^3'] =\
    correlations*correlations*correlations
X = bias_accuracy_tradeoff[['Correlation to biased features',
                            'Correlation to biased features ^2',
                            'Correlation to biased features ^3']]
X = sm.add_constant(X)
Y = bias_accuracy_tradeoff['Accuracy of feature group']

model = sm.OLS(Y, X).fit()
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                 OLS Regression Results
# =====================================================================================
# Dep. Variable:     Accuracy of feature group   R-squared:                       0.890
# Model:                                   OLS   Adj. R-squared:                  0.866
# Method:                        Least Squares   F-statistic:                     37.62
# Date:                       Wed, 05 Dec 2018   Prob (F-statistic):           5.95e-07
# Time:                               13:31:53   Log-Likelihood:                 26.274
# No. Observations:                         18   AIC:                            -44.55
# Df Residuals:                             14   BIC:                            -40.99
# Df Model:                                  3
# Covariance Type:                   nonrobust
# =====================================================================================================
#                                         coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------------
# const                                -0.4484      0.110     -4.076      0.001      -0.684      -0.212
# Correlation to biased features        4.6903      0.832      5.637      0.000       2.906       6.475
# Correlation to biased features ^2    -7.8073      1.773     -4.403      0.001     -11.611      -4.004
# Correlation to biased features ^3     4.2424      1.115      3.806      0.002       1.852       6.633
# ==============================================================================
# Omnibus:                        1.282   Durbin-Watson:                   2.223
# Prob(Omnibus):                  0.527   Jarque-Bera (JB):                0.677
# Skew:                          -0.473   Prob(JB):                        0.713
# Kurtosis:                       2.906   Cond. No.                         184.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
fig, ax = plt.subplots()
sm.graphics.plot_fit(model, 1, ax=ax)
plt.show()

# %%
X = bias_accuracy_tradeoff[['Correlation to biased features',
                            'Correlation to biased features ^2']]
X = sm.add_constant(X)
Y = bias_accuracy_tradeoff['Accuracy of feature group']

model = sm.OLS(Y, X).fit()

fig, ax = plt.subplots()
sm.graphics.plot_fit(model, 1, ax=ax)
plt.show()

# %%
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                 OLS Regression Results
# =====================================================================================
# Dep. Variable:     Accuracy of feature group   R-squared:                       0.775
# Model:                                   OLS   Adj. R-squared:                  0.746
# Method:                        Least Squares   F-statistic:                     25.90
# Date:                       Wed, 05 Dec 2018   Prob (F-statistic):           1.36e-05
# Time:                               15:45:55   Log-Likelihood:                 19.880
# No. Observations:                         18   AIC:                            -33.76
# Df Residuals:                             15   BIC:                            -31.09
# Df Model:                                  2
# Covariance Type:                   nonrobust
# =====================================================================================================
#                                         coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------------
# const                                -0.1032      0.086     -1.202      0.248      -0.286       0.080
# Correlation to biased features        1.6941      0.372      4.559      0.000       0.902       2.486
# Correlation to biased features ^2    -1.1255      0.346     -3.257      0.005      -1.862      -0.389
# ==============================================================================
# Omnibus:                        2.199   Durbin-Watson:                   1.172
# Prob(Omnibus):                  0.333   Jarque-Bera (JB):                0.653
# Skew:                          -0.300   Prob(JB):                        0.721
# Kurtosis:                       3.715   Cond. No.                         29.5
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
import matplotlib.pyplot as plt; plt.rcdefaults()
import numpy as np
import matplotlib.pyplot as plt
 
features = tuple(features_correlation_thresholds.keys())
y_pos = np.arange(len(features))
 
plt.bar(y_pos, lm_accuracies.values(), align='center', alpha=0.3)
plt.xticks(y_pos, features)
plt.ylabel('Accuracy')
plt.title('Linear Model Accuracies')
plt.xticks(rotation=30)
plt.plot(lm_accuracies.values(), color='red', alpha=0.5)
 
plt.show()

# %%
from sklearn.model_selection import cross_val_score
from sklearn import preprocessing
from sklearn import svm
import warnings
warnings.filterwarnings('ignore')

svm = svm.LinearSVR()
svm_accuracies = []

print('   Support Vector Machine   ')
print('----------------------------')

for name, feature_group in features_correlation_thresholds.items():
    X = df[feature_group]
    print(name)
    scores = cross_val_score(svm, X, y, cv=5)
    print('  Mse: '+str(abs(scores).mean()))
    svm_accuracies.append(abs(scores).mean())
# Out:
#    Support Vector Machine
# ----------------------------
# 0.1
#   Mse: 0.26120981440643937
# 0.15
#   Mse: 1.475693192394589
# 0.2
#   Mse: 1.403076495416911
# 0.25
#   Mse: 0.38961696522765665
# 0.3
#   Mse: 0.18634228806274364
# 0.35
#   Mse: 0.8023720674883977
# 0.4
#   Mse: 0.9675422179287974
# 0.45
#   Mse: 0.5029011575805189
# 0.5
#   Mse: 0.36824242262233275
# 0.55
#   Mse: 0.389647124907938
# 0.6
#   Mse: 0.36164414543600604
# 0.65
#   Mse: 0.6372041574571469
# 0.7
#   Mse: 0.5075219548938902
# 0.75
#   Mse: 0.21076489189496167
# 0.8
#   Mse: 2.2260173012898363
# 0.85
#   Mse: 3.1662892912508673
# 0.9
#   Mse: 0.885622588148426
# 0.95
#   Mse: 5.626268719203976

# %%
import matplotlib.pyplot as plt; plt.rcdefaults()
import numpy as np
import matplotlib.pyplot as plt
 
features = tuple(features_correlation_thresholds.keys())
y_pos = np.arange(len(features))
 
plt.bar(y_pos, svm_accuracies, align='center', alpha=0.3)
plt.xticks(y_pos, features)
plt.ylabel('MSE')
plt.title('SVM MSE')
plt.xticks(rotation=30)
plt.plot(svm_accuracies, color='red', alpha =0.5)
 
plt.show()

# %% [markdown]
# ## Method 3
# - Use step-wise regression to determine the best models and their corresponding features
# - Pick the model with the least number of biased/protected features

# %% [markdown]
# According to stackexchange, stepwise regression may not be the most legimate method for feature selection. After more research, there may or may not be more work into this method
#
# ref: https://stats.stackexchange.com/questions/20836/algorithms-for-automatic-model-selection/20856#20856
